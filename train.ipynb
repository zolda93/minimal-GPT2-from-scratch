# %%
cd /content/drive/MyDrive/deep learning/minimal-GPT2
# Out:
# /content/drive/MyDrive/deep learning/minimal-GPT2

# %%
from main import train
train()
# Out:
# Start Downloading data ...
# Extracting data...
# Start loading data...
# Finish loading data...
# Start building vocab...
# Begin preparing data...
# Begin preparing data...
# ...
# Train 20:   0%|          | 0/128 [00:00<?, ?it/s]
